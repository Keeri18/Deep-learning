# %%
from __future__ import print_function
import numpy as np 
from keras.datasets import mnist 
from keras.models import Sequential 
from keras.layers.core import Dense, Activation 
from tensorflow.keras.optimizers import SGD
from keras.utils import np_utils
np.random.seed(1671)  # for reproducibility

# %%
# network and training
NB_EPOCH = 200
BATCH_SIZE = 8
VERBOSE = 1
NB_CLASSES = 10
# number of outputs = number of digits
OPTIMIZER = SGD()
# SGD optimizer, explained later in this chapter
N_HIDDEN = 256
VALIDATION_SPLIT=0.2
# how much TRAIN is reserved for VALIDATION

# %%
import tensorflow
import keras

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
# data: shuffled and split between train and test sets
#
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# normalize
#
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# %%
# 10 outputs
# final stage is softmax

# %%
model = Sequential()
model.add(Dense(NB_CLASSES, input_shape=(RESHAPED,)))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy'])
history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=NB_EPOCH, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                7850
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 6000/6000 [==============================] - 31s 5ms/step - loss: 0.7982 - accuracy: 0.7955 - val_loss: 0.3617 - val_accuracy: 0.9043
# Epoch 2/200
# 6000/6000 [==============================] - 24s 4ms/step - loss: 0.3845 - accuracy: 0.8939 - val_loss: 0.3249 - val_accuracy: 0.9119
# Epoch 3/200
# 6000/6000 [==============================] - 26s 4ms/step - loss: 0.3472 - accuracy: 0.9021 - val_loss: 0.3117 - val_accuracy: 0.9130
# Epoch 4/200
# 6000/6000 [==============================] - 58s 10ms/step - loss: 0.3217 - accuracy: 0.9096 - val_loss: 0.3001 - val_accuracy: 0.9173
# Epoch 5/200
# 6000/6000 [==============================] - 40s 7ms/step - loss: 0.3104 - accuracy: 0.9138 - val_loss: 0.2952 - val_accuracy: 0.9181
# Epoch 6/200
# 6000/6000 [==============================] - 22s 4ms/step - loss: 0.3042 - accuracy: 0.9169 - val_loss: 0.2907 - val_accuracy: 0.9194
# Epoch 7/200
# 6000/6000 [==============================] - 20s 3ms/step - loss: 0.3012 - accuracy: 0.9168 - val_loss: 0.2864 - val_accuracy: 0.9211
# Epoch 8/200
# 6000/6000 [==============================] - 19s 3ms/step - loss: 0.2900 - accuracy: 0.9191 - val_loss: 0.2854 - val_accuracy: 0.9212
# Epoch 9/200
# 6000/6000 [==============================] - 18s 3ms/step - loss: 0.2836 - accuracy: 0.9189 - val_loss: 0.2820 - val_accuracy: 0.9217
# Epoch 10/200
# 6000/6000 [==============================] - 17s 3ms/step - loss: 0.2893 - accuracy: 0.9192 - val_loss: 0.2799 - val_accuracy: 0.9214
# Epoch 11/200
# 6000/6000 [==============================] - 30s 5ms/step - loss: 0.2902 - accuracy: 0.9193 - val_loss: 0.2795 - val_accuracy: 0.9233
# Epoch 12/200
# 6000/6000 [==============================] - 34s 6ms/step - loss: 0.2853 - accuracy: 0.9212 - val_loss: 0.2776 - val_accuracy: 0.9223
# Epoch 13/200
# 6000/6000 [==============================] - 28s 5ms/step - loss: 0.2804 - accuracy: 0.9216 - val_loss: 0.2758 - val_accuracy: 0.9242
# Epoch 14/200
200
# 6000/6000 [==============================] - 15s 2ms/step - loss: 0.2521 - accuracy: 0.9288 - val_loss: 0.2684 - val_accuracy: 0.9262
# Epoch 43/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2565 - accuracy: 0.9297 - val_loss: 0.2672 - val_accuracy: 0.9277
# Epoch 44/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2457 - accuracy: 0.9322 - val_loss: 0.2689 - val_accuracy: 0.9274
# Epoch 45/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2492 - accuracy: 0.9312 - val_loss: 0.2682 - val_accuracy: 0.9271
# Epoch 46/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2487 - accuracy: 0.9310 - val_loss: 0.2669 - val_accuracy: 0.9271
# Epoch 47/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2518 - accuracy: 0.9290 - val_loss: 0.2682 - val_accuracy: 0.9277
# Epoch 48/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2621 - accuracy: 0.9270 - val_loss: 0.2680 - val_accuracy: 0.9273
# Epoch 49/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2479 - accuracy: 0.9301 - val_loss: 0.2678 - val_accuracy: 0.9273
# Epoch 50/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2504 - accuracy: 0.9305 - val_loss: 0.2672 - val_accuracy: 0.9284
# Epoch 51/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2527 - accuracy: 0.9291 - val_loss: 0.2668 - val_accuracy: 0.9279
# Epoch 52/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2492 - accuracy: 0.9304 - val_loss: 0.2670 - val_accuracy: 0.9287
# Epoch 53/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2511 - accuracy: 0.9303 - val_loss: 0.2668 - val_accuracy: 0.9284
# Epoch 54/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2471 - accuracy: 0.9323 - val_loss: 0.2668 - val_accuracy: 0.9283
# Epoch 55/200
# 6000/6000 [==============================] - 13s 2ms/step - loss: 0.2535 - accuracy: 0.9288 - val_loss: 0.2663 - val_accuracy: 0.9285
# Epoch 56/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2470 - accuracy: 0.9313 - val_loss: 0.2662 - val_accuracy: 0.9286
# Epoch 57/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2520 - accuracy: 0.9304 - val_loss: 0.2686 - val_accuracy: 0.9259
# Epoch 58/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2471 - accuracy: 0.9312 - val_loss: 0.2682 - val_accuracy: 0.9277
# Epoch 59/200
# 6000/6000 [==============================] - 15s 2ms/step - loss: 0.2541 - accuracy: 0.9304 - val_loss: 0.2669 - val_accuracy: 0.9284
# Epoch 60/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2498 - accuracy: 0.9307 - val_loss: 0.2696 - val_accuracy: 0.9257
# Epoch 61/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2453 - accuracy: 0.9316 - val_loss: 0.2662 - val_accuracy: 0.9282
# Epoch 62/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2450 - accuracy: 0.9301 - val_loss: 0.2679 - val_accuracy: 0.9268
# Epoch 63/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2486 - accuracy: 0.9316 - val_loss: 0.2662 - val_accuracy: 0.9281
# Epoch 64/200
# 6000/6000 [==============================] - 19s 3ms/step - loss: 0.2509 - accuracy: 0.9304 - val_loss: 0.2679 - val_accuracy: 0.9271
# Epoch 65/200
# 6000/6000 [==============================] - 17s 3ms/step - loss: 0.2532 - accuracy: 0.9304 - val_loss: 0.2687 - val_accuracy: 0.9273
# Epoch 66/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2492 - accuracy: 0.9309 - val_loss: 0.2675 - val_accuracy: 0.9276
# Epoch 67/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2483 - accuracy: 0.9303 - val_loss: 0.2673 - val_accuracy: 0.9277
# Epoch 68/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.2432 - accuracy: 0.9317 - val_loss: 0.2680 - val_accuracy: 0.9279
# Epoch 69/200
# 6000/6000 [==============================] - 14s 2ms/step - loss: 0.
200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2359 - accuracy: 0.9337 - val_loss: 0.2701 - val_accuracy: 0.9269
# Epoch 128/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2329 - accuracy: 0.9343 - val_loss: 0.2694 - val_accuracy: 0.9277
# Epoch 129/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2391 - accuracy: 0.9343 - val_loss: 0.2694 - val_accuracy: 0.9286
# Epoch 130/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2437 - accuracy: 0.9346 - val_loss: 0.2681 - val_accuracy: 0.9282
# Epoch 131/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2348 - accuracy: 0.9339 - val_loss: 0.2701 - val_accuracy: 0.9277
# Epoch 132/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2354 - accuracy: 0.9343 - val_loss: 0.2717 - val_accuracy: 0.9270
# Epoch 133/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2290 - accuracy: 0.9365 - val_loss: 0.2686 - val_accuracy: 0.9274
# Epoch 134/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2377 - accuracy: 0.9340 - val_loss: 0.2691 - val_accuracy: 0.9277
# Epoch 135/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2383 - accuracy: 0.9345 - val_loss: 0.2687 - val_accuracy: 0.9287
# Epoch 136/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2390 - accuracy: 0.9340 - val_loss: 0.2705 - val_accuracy: 0.9275
# Epoch 137/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2380 - accuracy: 0.9336 - val_loss: 0.2697 - val_accuracy: 0.9289
# Epoch 138/200
# 6000/6000 [==============================] - 18s 3ms/step - loss: 0.2312 - accuracy: 0.9366 - val_loss: 0.2698 - val_accuracy: 0.9283
# Epoch 139/200
# 6000/6000 [==============================] - 15s 2ms/step - loss: 0.2337 - accuracy: 0.9361 - val_loss: 0.2693 - val_accuracy: 0.9283
# Epoch 140/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2287 - accuracy: 0.9388 - val_loss: 0.2687 - val_accuracy: 0.9279
# Epoch 141/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2386 - accuracy: 0.9346 - val_loss: 0.2687 - val_accuracy: 0.9277
# Epoch 142/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2426 - accuracy: 0.9338 - val_loss: 0.2723 - val_accuracy: 0.9266
# Epoch 143/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2383 - accuracy: 0.9339 - val_loss: 0.2714 - val_accuracy: 0.9265
# Epoch 144/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2435 - accuracy: 0.9334 - val_loss: 0.2704 - val_accuracy: 0.9280
# Epoch 145/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2345 - accuracy: 0.9355 - val_loss: 0.2688 - val_accuracy: 0.9284
# Epoch 146/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2368 - accuracy: 0.9339 - val_loss: 0.2696 - val_accuracy: 0.9278
# Epoch 147/200
# 6000/6000 [==============================] - 15s 2ms/step - loss: 0.2358 - accuracy: 0.9366 - val_loss: 0.2696 - val_accuracy: 0.9274
# Epoch 148/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2307 - accuracy: 0.9350 - val_loss: 0.2695 - val_accuracy: 0.9284
# Epoch 149/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2406 - accuracy: 0.9338 - val_loss: 0.2702 - val_accuracy: 0.9268
# Epoch 150/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2305 - accuracy: 0.9373 - val_loss: 0.2691 - val_accuracy: 0.9269
# Epoch 151/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2303 - accuracy: 0.9360 - val_loss: 0.2707 - val_accuracy: 0.9265
# Epoch 152/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2340 - accuracy: 0.9341 - val_loss: 0.2704 - val_accuracy: 0.9270
# Epoch 153/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2302 - accuracy: 0.9364 - val_loss: 0.2703 - val_accuracy: 0.9268
# Epoch 154/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2321 - accuracy: 0.9358 - val_loss: 0.2704 - val_accuracy: 0.9275
# Epoch 155/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2358 - accuracy: 0.9341 - val_loss: 0.2705 - val_accuracy: 0.9272
# Epoch 156/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2325 - accuracy: 0.9349 - val_loss: 0.2700 - val_accuracy: 0.9283
# Epoch 157/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2339 - accuracy: 0.9350 - val_loss: 0.2729 - val_accuracy: 0.9268
# Epoch 158/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.
200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2311 - accuracy: 0.9347 - val_loss: 0.2712 - val_accuracy: 0.9272
# Epoch 189/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2274 - accuracy: 0.9370 - val_loss: 0.2719 - val_accuracy: 0.9273
# Epoch 190/200
# 6000/6000 [==============================] - 16s 3ms/step - loss: 0.2290 - accuracy: 0.9353 - val_loss: 0.2721 - val_accuracy: 0.9266
# Epoch 191/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2315 - accuracy: 0.9370 - val_loss: 0.2721 - val_accuracy: 0.9273
# Epoch 192/200
# 6000/6000 [==============================] - 15s 2ms/step - loss: 0.2269 - accuracy: 0.9380 - val_loss: 0.2710 - val_accuracy: 0.9273
# Epoch 193/200
# 6000/6000 [==============================] - 17s 3ms/step - loss: 0.2266 - accuracy: 0.9380 - val_loss: 0.2720 - val_accuracy: 0.9267- loss: 0.2265 -
# Epoch 194/200
# 6000/6000 [==============================] - 15s 2ms/step - loss: 0.2380 - accuracy: 0.9345 - val_loss: 0.2706 - val_accuracy: 0.9277
# Epoch 195/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2234 - accuracy: 0.9374 - val_loss: 0.2736 - val_accuracy: 0.9268
# Epoch 196/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2262 - accuracy: 0.9382 - val_loss: 0.2723 - val_accuracy: 0.9262
# Epoch 197/200
# 6000/6000 [==============================] - 15s 2ms/step - loss: 0.2345 - accuracy: 0.9352 - val_loss: 0.2709 - val_accuracy: 0.9273
# Epoch 198/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2281 - accuracy: 0.9370 - val_loss: 0.2727 - val_accuracy: 0.9273
# Epoch 199/200
# 6000/6000 [==============================] - 15s 3ms/step - loss: 0.2309 - accuracy: 0.9366 - val_loss: 0.2725 - val_accuracy: 0.9277
# Epoch 200/200
# 6000/6000 [==============================] - 15s 2ms/step - loss: 0.2332 - accuracy: 0.9349 - val_loss: 0.2723 - val_accuracy: 0.9276
# 313/313 [==============================] - 2s 3ms/step - loss: 0.2724 - accuracy: 0.9250
#
# Test score: 0.2723957896232605
# Test accuracy: 0.925000011920929

# %% [markdown]
# # 200 EPOCHS BATCH_SIZE= 8 N_HIDDEN=256 TEST_ACCURACY=0.9241999

# %% [markdown]
# # 100 epochs test accuracy 0.9197999
# # 200 epochs test accuracy 0.9225999
# # 300 epochs test accuracy 0.9235
# # 400 epochs test accuracy 0.9243999
# # 500 epochs test accuracy 0.9248999
# # 600 epochs test accuracy 0.9261

# %% [markdown]
# # 200 epochs
# # batch_size = 4096 test accuracy = 0.8878999
# # batch_size = 128  test accuracy = 0.9225999
# # batch_size = 64   test accuracy =
# # batch_size = 32   test accuracy = 0.9255999
# # batch_size = 16   test accuracy =
# # batch_size = 8    test accuracy =  0.9258999

# %% [markdown]
# # VALIDATION_SPLIT=0.1
# # ACCURACY=0.1

# %%
# network and training
NB_EPOCH = 200
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10
# number of outputs = number of digits
OPTIMIZER = SGD()
# SGD optimizer, explained later in this chapter
N_HIDDEN = 128
VALIDATION_SPLIT=0.1
# how much TRAIN is reserved for VALIDATION

# %%
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# normalize
#
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# %%
model = Sequential()
model.add(Dense(NB_CLASSES, input_shape=(RESHAPED,)))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy'])
history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=NB_EPOCH, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 10)                7850
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 422/422 [==============================] - 4s 5ms/step - loss: 2.3024 - accuracy: 0.1132 - val_loss: 2.3020 - val_accuracy: 0.1050
# Epoch 2/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3016 - accuracy: 0.1126 - val_loss: 2.3018 - val_accuracy: 0.1050
# Epoch 3/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3013 - accuracy: 0.1143 - val_loss: 2.3017 - val_accuracy: 0.1050
# Epoch 4/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3012 - accuracy: 0.1122 - val_loss: 2.3017 - val_accuracy: 0.1050
# Epoch 5/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3008 - accuracy: 0.1139 - val_loss: 2.3016 - val_accuracy: 0.1050
# Epoch 6/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3009 - accuracy: 0.1132 - val_loss: 2.3016 - val_accuracy: 0.1050
# Epoch 7/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3006 - accuracy: 0.1142 - val_loss: 2.3015 - val_accuracy: 0.1050
# Epoch 8/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3003 - accuracy: 0.1158 - val_loss: 2.3014 - val_accuracy: 0.1050
# Epoch 9/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3010 - accuracy: 0.1116 - val_loss: 2.3014 - val_accuracy: 0.1050
# Epoch 10/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3005 - accuracy: 0.1126 - val_loss: 2.3013 - val_accuracy: 0.1050
# Epoch 11/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3006 - accuracy: 0.1130 - val_loss: 2.3012 - val_accuracy: 0.1050
# Epoch 12/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3007 - accuracy: 0.1117 - val_loss: 2.3012 - val_accuracy: 0.1050
# Epoch 13/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3005 - accuracy: 0.1118 - val_loss: 2.3011 - val_accuracy: 0.1050
# Epoch 14/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3001 - accuracy: 0.1131 - val_loss: 2.3010 - val_accuracy: 0.1050
# Epoch 15/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3004 - accuracy: 0.1109 - val_loss: 2.3010 - val_accuracy: 0.1050
# Epoch 16/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2999 - accuracy: 0.1134 - val_loss: 2.3009 - val_accuracy: 0.1050
# Epoch 17/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3002 - accuracy: 0.1130 - val_loss: 2.3008 - val_accuracy: 0.1050
# Epoch 18/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3000 - accuracy: 0.1130 - val_loss: 2.3007 - val_accuracy: 0.1050
# Epoch 19/200
# 422/422 [==============================] - 2s 5ms/step - loss: 2.2998 - accuracy: 0.1135 - val_loss: 2.3006 - val_accuracy: 0.1050
# Epoch 20/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2996 - accuracy: 0.1141 - val_loss: 2.3006 - val_accuracy: 0.1050
# Epoch 21/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2994 - accuracy: 0.1154 - val_loss: 2.3005 - val_accuracy: 0.1050
# Epoch 22/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2995 - accuracy: 0.1157 - val_loss: 2.3004 - val_accuracy: 0.1050
# Epoch 23/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2991 - accuracy: 0.1152 - val_loss: 2.3003 - val_accuracy: 0.1050
# Epoch 24/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2996 - accuracy: 0.1128 - val_loss: 2.3003 - val_accuracy: 0.1050
# Epoch 25/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.3000 - accuracy: 0.1099 - val_loss: 2.3002 - val_accuracy: 0.1050
# Epoch 26/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2995 - accuracy: 0.1123 - val_loss: 2.3001 - val_accuracy: 0.1050
# Epoch 27/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2991 - accuracy: 0.1139 - val_loss: 2.3001 - val_accuracy: 0.1050
# Epoch 28/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2993 - accuracy: 0.1139 - val_loss: 2.3000 - val_accuracy: 0.1050
# Epoch 29/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2990 - accuracy: 0.1140 - val_loss: 2.2999 - val_accuracy: 0.1050
# Epoch 30/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2989 - accuracy: 0.1142 - val_loss: 2.2998 - val_accuracy: 0.1050
# Epoch 31/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2994 - accuracy: 0.1116 - val_loss: 2.2997 - val_accuracy: 0.1050
# Epoch 32/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2993 - accuracy: 0.1111 - val_loss: 2.2997 - val_accuracy: 0.1050
# Epoch 33/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2991 - accuracy: 0.1110 - val_loss: 2.2996 - val_accuracy: 0.1050
# Epoch 34/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2992 - accuracy: 0.1116 - val_loss: 2.2995 - val_accuracy: 0.1050
# Epoch 35/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2987 - accuracy: 0.1136 - val_loss: 2.2994 - val_accuracy: 0.1050
# Epoch 36/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2987 - accuracy: 0.1138 - val_loss: 2.2994 - val_accuracy: 0.1050
# Epoch 37/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2990 - accuracy: 0.1119 - val_loss: 2.2993 - val_accuracy: 0.1050
# Epoch 38/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2986 - accuracy: 0.1132 - val_loss: 2.2992 - val_accuracy: 0.1050
# Epoch 39/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2981 - accuracy: 0.1146 - val_loss: 2.2991 - val_accuracy: 0.1050
# Epoch 40/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2991 - accuracy: 0.1094 - val_loss: 2.2991 - val_accuracy: 0.1050
# Epoch 41/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2985 - accuracy: 0.1132 - val_loss: 2.2990 - val_accuracy: 0.1050
# Epoch 42/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2982 - accuracy: 0.1136 - val_loss: 2.2989 - val_accuracy: 0.1050
# Epoch 43/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2979 - accuracy: 0.1149 - val_loss: 2.2988 - val_accuracy: 0.1050
# Epoch 44/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2981 - accuracy: 0.1117 - val_loss: 2.2988 - val_accuracy: 0.1050
# Epoch 45/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2981 - accuracy: 0.1138 - val_loss: 2.2987 - val_accuracy: 0.1050
# Epoch 46/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2985 - accuracy: 0.1107 - val_loss: 2.2986 - val_accuracy: 0.1050
# Epoch 47/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2979 - accuracy: 0.1121 - val_loss: 2.2986 - val_accuracy: 0.1050
# Epoch 48/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2978 - accuracy: 0.1144 - val_loss: 2.2985 - val_accuracy: 0.1050
# Epoch 49/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2976 - accuracy: 0.1147 - val_loss: 2.2984 - val_accuracy: 0.1050
# Epoch 50/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2977 - accuracy: 0.1130 - val_loss: 2.2983 - val_accuracy: 0.1050
# Epoch 51/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2971 - accuracy: 0.1154 - val_loss: 2.2983 - val_accuracy: 0.1050
# Epoch 52/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2977 - accuracy: 0.1120 - val_loss: 2.2982 - val_accuracy: 0.1050
# Epoch 53/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2979 - accuracy: 0.1124 - val_loss: 2.2981 - val_accuracy: 0.1050
# Epoch 54/200
# 422/422 [==============================] - ETA: 0s - loss: 2.2975 - accuracy: 0.11 - 2s 4ms/step - loss: 2.2975 - accuracy: 0.1123 - val_loss: 2.2980 - val_accuracy: 0.1050
# Epoch 55/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2973 - accuracy: 0.1125 - val_loss: 2.2980 - val_accuracy: 0.1050
# Epoch 56/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2974 - accuracy: 0.1137 - val_loss: 2.2979 - val_accuracy: 0.1050
# Epoch 57/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2971 - accuracy: 0.1146 - val_loss: 2.2978 - val_accuracy: 0.1050
# Epoch 58/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2969 - accuracy: 0.1151 - val_loss: 2.2977 - val_accuracy: 0.1050
# Epoch 59/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2969 - accuracy: 0.1135 - val_loss: 2.2977 - val_accuracy: 0.1050
# Epoch 60/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2967 - accuracy: 0.1141 - val_loss: 2.2976 - val_accuracy: 0.1050
# Epoch 61/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.
200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2943 - accuracy: 0.1156 - val_loss: 2.2953 - val_accuracy: 0.1050
# Epoch 92/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2946 - accuracy: 0.1145 - val_loss: 2.2952 - val_accuracy: 0.1050
# Epoch 93/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2948 - accuracy: 0.1126 - val_loss: 2.2951 - val_accuracy: 0.1050
# Epoch 94/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2944 - accuracy: 0.1136 - val_loss: 2.2951 - val_accuracy: 0.1050
# Epoch 95/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2945 - accuracy: 0.1131 - val_loss: 2.2950 - val_accuracy: 0.1050
# Epoch 96/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2945 - accuracy: 0.1132 - val_loss: 2.2949 - val_accuracy: 0.1050
# Epoch 97/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2945 - accuracy: 0.1133 - val_loss: 2.2948 - val_accuracy: 0.1050
# Epoch 98/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2941 - accuracy: 0.1134 - val_loss: 2.2948 - val_accuracy: 0.1050
# Epoch 99/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2943 - accuracy: 0.1125 - val_loss: 2.2947 - val_accuracy: 0.1050
# Epoch 100/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2942 - accuracy: 0.1140 - val_loss: 2.2946 - val_accuracy: 0.1050
# Epoch 101/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2937 - accuracy: 0.1145 - val_loss: 2.2945 - val_accuracy: 0.1050
# Epoch 102/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2936 - accuracy: 0.1148 - val_loss: 2.2945 - val_accuracy: 0.1050
# Epoch 103/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2944 - accuracy: 0.1110 - val_loss: 2.2944 - val_accuracy: 0.1050
# Epoch 104/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2936 - accuracy: 0.1144 - val_loss: 2.2943 - val_accuracy: 0.1050
# Epoch 105/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2935 - accuracy: 0.1155 - val_loss: 2.2942 - val_accuracy: 0.1050
# Epoch 106/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2938 - accuracy: 0.1124 - val_loss: 2.2942 - val_accuracy: 0.1050
# Epoch 107/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2939 - accuracy: 0.1131 - val_loss: 2.2941 - val_accuracy: 0.1050
# Epoch 108/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2934 - accuracy: 0.1137 - val_loss: 2.2940 - val_accuracy: 0.1050
# Epoch 109/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2933 - accuracy: 0.1146 - val_loss: 2.2939 - val_accuracy: 0.1050
# Epoch 110/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2934 - accuracy: 0.1121 - val_loss: 2.2939 - val_accuracy: 0.1050
# Epoch 111/200
# 422/422 [==============================] - 2s 5ms/step - loss: 2.2937 - accuracy: 0.1112 - val_loss: 2.2938 - val_accuracy: 0.1050
# Epoch 112/200
# 422/422 [==============================] - 2s 5ms/step - loss: 2.2930 - accuracy: 0.1140 - val_loss: 2.2937 - val_accuracy: 0.1050
# Epoch 113/200
# 422/422 [==============================] - 2s 5ms/step - loss: 2.2927 - accuracy: 0.1145 - val_loss: 2.2937 - val_accuracy: 0.1050
# Epoch 114/200
# 422/422 [==============================] - 2s 5ms/step - loss: 2.2931 - accuracy: 0.1137 - val_loss: 2.2936 - val_accuracy: 0.1050
# Epoch 115/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2929 - accuracy: 0.1134 - val_loss: 2.2935 - val_accuracy: 0.1050
# Epoch 116/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2926 - accuracy: 0.1155 - val_loss: 2.2935 - val_accuracy: 0.1050
# Epoch 117/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2930 - accuracy: 0.1132 - val_loss: 2.2934 - val_accuracy: 0.1050
# Epoch 118/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2930 - accuracy: 0.1126 - val_loss: 2.2933 - val_accuracy: 0.1050
# Epoch 119/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2928 - accuracy: 0.1138 - val_loss: 2.2932 - val_accuracy: 0.1050
# Epoch 120/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2927 - accuracy: 0.1132 - val_loss: 2.2931 - val_accuracy: 0.1050
# Epoch 121/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2925 - accuracy: 0.1140 - val_loss: 2.2931 - val_accuracy: 0.1050
# Epoch 122/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2926 - accuracy: 0.1114 - val_loss: 2.2930 - val_accuracy: 0.1050
# Epoch 123/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2924 - accuracy: 0.1145 - val_loss: 2.2929 - val_accuracy: 0.1050
# Epoch 124/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2923 - accuracy: 0.1151 - val_loss: 2.2929 - val_accuracy: 0.1050
# Epoch 125/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2921 - accuracy: 0.1132 - val_loss: 2.2928 - val_accuracy: 0.1050
# Epoch 126/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2924 - accuracy: 0.1132 - val_loss: 2.2927 - val_accuracy: 0.1050
# Epoch 127/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2918 - accuracy: 0.1172 - val_loss: 2.2926 - val_accuracy: 0.1050
# Epoch 128/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2922 - accuracy: 0.1125 - val_loss: 2.2926 - val_accuracy: 0.1050
# Epoch 129/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2920 - accuracy: 0.1132 - val_loss: 2.2925 - val_accuracy: 0.1050
# Epoch 130/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2924 - accuracy: 0.1116 - val_loss: 2.2924 - val_accuracy: 0.1050
# Epoch 131/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2914 - accuracy: 0.1150 - val_loss: 2.2923 - val_accuracy: 0.1050
# Epoch 132/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2917 - accuracy: 0.1145 - val_loss: 2.2922 - val_accuracy: 0.1050
# Epoch 133/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2916 - accuracy: 0.1137 - val_loss: 2.2922 - val_accuracy: 0.1050
# Epoch 134/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2915 - accuracy: 0.1128 - val_loss: 2.2921 - val_accuracy: 0.1050
# Epoch 135/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2915 - accuracy: 0.1147 - val_loss: 2.2920 - val_accuracy: 0.1050
# Epoch 136/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2917 - accuracy: 0.1121 - val_loss: 2.2920 - val_accuracy: 0.1050
# Epoch 137/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2913 - accuracy: 0.1128 - val_loss: 2.2919 - val_accuracy: 0.1050
# Epoch 138/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2915 - accuracy: 0.1117 - val_loss: 2.2918 - val_accuracy: 0.1050
# Epoch 139/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2915 - accuracy: 0.1119 - val_loss: 2.2918 - val_accuracy: 0.1050
# Epoch 140/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2912 - accuracy: 0.1140 - val_loss: 2.2917 - val_accuracy: 0.1050
# Epoch 141/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2913 - accuracy: 0.1127 - val_loss: 2.2916 - val_accuracy: 0.1050
# Epoch 142/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2911 - accuracy: 0.1141 - val_loss: 2.2915 - val_accuracy: 0.1050
# Epoch 143/200
# 422/422 [==============================] - 2s 5ms/step - loss: 2.2916 - accuracy: 0.1107 - val_loss: 2.2915 - val_accuracy: 0.1050
# Epoch 144/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2908 - accuracy: 0.1133 - val_loss: 2.2914 - val_accuracy: 0.1050
# Epoch 145/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2910 - accuracy: 0.1120 - val_loss: 2.2913 - val_accuracy: 0.1050
# Epoch 146/200
# 422/422 [==============================] - 2s 5ms/step - loss: 2.2906 - accuracy: 0.1140 - val_loss: 2.2913 - val_accuracy: 0.1050
# Epoch 147/200
# 422/422 [==============================] - 2s 5ms/step - loss: 2.2907 - accuracy: 0.1129 - val_loss: 2.2912 - val_accuracy: 0.1050
# Epoch 148/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.
200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2883 - accuracy: 0.1142 - val_loss: 2.2889 - val_accuracy: 0.1050
# Epoch 179/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2889 - accuracy: 0.1099 - val_loss: 2.2888 - val_accuracy: 0.1050
# Epoch 180/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2885 - accuracy: 0.1119 - val_loss: 2.2887 - val_accuracy: 0.1050
# Epoch 181/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2886 - accuracy: 0.1118 - val_loss: 2.2887 - val_accuracy: 0.1050
# Epoch 182/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2886 - accuracy: 0.1120 - val_loss: 2.2886 - val_accuracy: 0.1050
# Epoch 183/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2878 - accuracy: 0.1144 - val_loss: 2.2885 - val_accuracy: 0.1050
# Epoch 184/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2882 - accuracy: 0.1132 - val_loss: 2.2884 - val_accuracy: 0.1050
# Epoch 185/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2887 - accuracy: 0.1109 - val_loss: 2.2884 - val_accuracy: 0.1050
# Epoch 186/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2885 - accuracy: 0.1107 - val_loss: 2.2883 - val_accuracy: 0.1050
# Epoch 187/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2883 - accuracy: 0.1126 - val_loss: 2.2882 - val_accuracy: 0.1050
# Epoch 188/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2876 - accuracy: 0.1145 - val_loss: 2.2881 - val_accuracy: 0.1050
# Epoch 189/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2878 - accuracy: 0.1139 - val_loss: 2.2881 - val_accuracy: 0.1050
# Epoch 190/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2868 - accuracy: 0.1184 - val_loss: 2.2880 - val_accuracy: 0.1050
# Epoch 191/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2878 - accuracy: 0.1121 - val_loss: 2.2879 - val_accuracy: 0.1050
# Epoch 192/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2876 - accuracy: 0.1128 - val_loss: 2.2878 - val_accuracy: 0.1050
# Epoch 193/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2873 - accuracy: 0.1148 - val_loss: 2.2878 - val_accuracy: 0.1050
# Epoch 194/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2878 - accuracy: 0.1116 - val_loss: 2.2877 - val_accuracy: 0.1050
# Epoch 195/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2874 - accuracy: 0.1117 - val_loss: 2.2876 - val_accuracy: 0.1050
# Epoch 196/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2872 - accuracy: 0.1139 - val_loss: 2.2876 - val_accuracy: 0.1050
# Epoch 197/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2872 - accuracy: 0.1143 - val_loss: 2.2875 - val_accuracy: 0.1050
# Epoch 198/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2870 - accuracy: 0.1138 - val_loss: 2.2874 - val_accuracy: 0.1050
# Epoch 199/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2869 - accuracy: 0.1142 - val_loss: 2.2873 - val_accuracy: 0.1050
# Epoch 200/200
# 422/422 [==============================] - 2s 4ms/step - loss: 2.2877 - accuracy: 0.1114 - val_loss: 2.2873 - val_accuracy: 0.1050
# 313/313 [==============================] - 1s 2ms/step - loss: 2.2865 - accuracy: 0.1135
#
# Test score: 2.2865164279937744
# Test accuracy: 0.11349999904632568

# %% [markdown]
# # VALIDATION_SPLIT=0.3 TO 0.9
# only validation split=0.2 gives accuracy around 92%

# %%
# network and training
NB_EPOCH = 200
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10
# number of outputs = number of digits
OPTIMIZER = SGD()
# SGD optimizer, explained later in this chapter
N_HIDDEN = 128
VALIDATION_SPLIT=0.8
# how much TRAIN is reserved for VALIDATION

# %%
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# normalize
#
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# %%
model = Sequential()
model.add(Dense(NB_CLASSES, input_shape=(RESHAPED,)))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy'])
history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=NB_EPOCH, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None,
- val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 170/200
# 94/94 [==============================] - 1s 13ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 171/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.3014 - accuracy: 0.1100 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 172/200
# 94/94 [==============================] - 1s 14ms/step - loss: 2.2995 - accuracy: 0.1164 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 173/200
# 94/94 [==============================] - 1s 13ms/step - loss: 2.3007 - accuracy: 0.1130 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 174/200
# 94/94 [==============================] - 1s 13ms/step - loss: 2.3016 - accuracy: 0.1115 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 175/200
# 94/94 [==============================] - 1s 13ms/step - loss: 2.3011 - accuracy: 0.1134 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 176/200
# 94/94 [==============================] - 1s 13ms/step - loss: 2.3001 - accuracy: 0.1132 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 177/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.2999 - accuracy: 0.1130 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 178/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.3003 - accuracy: 0.1154 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 179/200
# 94/94 [==============================] - 2s 19ms/step - loss: 2.3005 - accuracy: 0.1119 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 180/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.3011 - accuracy: 0.1106 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 181/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.3005 - accuracy: 0.1096 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 182/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.3001 - accuracy: 0.1145 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 183/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.2996 - accuracy: 0.1173 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 184/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.3009 - accuracy: 0.1119 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 185/200
# 94/94 [==============================] - 2s 19ms/step - loss: 2.3007 - accuracy: 0.1128 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 186/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.3005 - accuracy: 0.1172 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 187/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.3002 - accuracy: 0.1124 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 188/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.3011 - accuracy: 0.1134 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 189/200
# 94/94 [==============================] - 2s 17ms/step - loss: 2.2999 - accuracy: 0.1149 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 190/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.2991 - accuracy: 0.1140 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 191/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.2997 - accuracy: 0.1166 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 192/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.3015 - accuracy: 0.1131 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 193/200
# 94/94 [==============================] - 2s 17ms/step - loss: 2.3006 - accuracy: 0.1085 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 194/200
# 94/94 [==============================] - 2s 18ms/step - loss: 2.3003 - accuracy: 0.1108 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 195/200
# 94/94 [==============================] - 1s 14ms/step - loss: 2.3000 - accuracy: 0.1143 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 196/200
# 94/94 [==============================] - 1s 14ms/step - loss: 2.3008 - accuracy: 0.1143 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 197/200
# 94/94 [==============================] - 1s 14ms/step - loss: 2.3010 - accuracy: 0.1076 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 198/200
# 94/94 [==============================] - 1s 14ms/step - loss: 2.2998 - accuracy: 0.1130 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 199/200
# 94/94 [==============================] - 1s 13ms/step - loss: 2.3000 - accuracy: 0.1140 - val_loss: 2.3016 - val_accuracy: 0.1123
# Epoch 200/200
# 94/94 [==============================] - 1s 13ms/step - loss: 2.3002 - accuracy: 0.1173 - val_loss: 2.3016 - val_accuracy: 0.1123
# 313/313 [==============================] - 1s 2ms/step - loss: 2.3013 - accuracy: 0.1135
#
# Test score: 2.3013110160827637
# Test accuracy: 0.11349999904632568

# %% [markdown]
# # CIFAR-10
# # EPOCH=200 BATCH SIZE=8 N_HIDDEN=128 Test accuracy=0.9265 //wat??
# # EPOCH=200 BATCH SIZE=8 N_HIDDEN=128 Test accuracy=0.9251

# %%
import tensorflow as tf
print(tf.__version__)
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# 2.5.0

# %%
# network and training
NB_EPOCH = 200
BATCH_SIZE = 8
VERBOSE = 1
NB_CLASSES = 10
# number of outputs = number of digits
OPTIMIZER = SGD()
# SGD optimizer, explained later in this chapter
N_HIDDEN = 128
VALIDATION_SPLIT=0.2
# how much TRAIN is reserved for VALIDATION

# %%
# data: shuffled and split between train and test sets
#
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# normalize
#
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# %%
# 10 outputs
# final stage is softmax

# %%
model = Sequential()
model.add(Dense(NB_CLASSES, input_shape=(RESHAPED,)))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy'])
history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=NB_EPOCH, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 10)                7850
# _________________________________________________________________
# activation_4 (Activation)    (None, 10)                0
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
#
# 6000/6000 [==============================] - 74s 12ms/step - loss: 0.2659 - accuracy: 0.9241 - val_loss: 0.2725 - val_accuracy: 0.92539s - loss: 0.2615  - ETA: 27s - l - ETA: 17s - loss: 0.2636 -
# Epoch 20/200
# 6000/6000 [==============================] - 74s 12ms/step - loss: 0.2644 - accuracy: 0.9273 - val_loss: 0.2714 - val_accuracy: 0.9250
# Epoch 21/200
# 6000/6000 [==============================] - 72s 12ms/step - loss: 0.2678 - accuracy: 0.9253 - val_loss: 0.2714 - val_accuracy: 0.9253
# Epoch 22/200
# 6000/6000 [==============================] - 60s 10ms/step - loss: 0.2619 - accuracy: 0.9257 - val_loss: 0.2716 - val_accuracy: 0.9250
# Epoch 23/200
# 5969/6000 [============================>.] - ETA: 0s - loss: 0.2681 - accuracy: 0.92

# %% [markdown]
# # NB_EPOCH=250 BATCH_SIZE=8 N_HIDDEN=1024 Test accuracy=

# %%
# network and training
NB_EPOCH = 250
BATCH_SIZE = 8
VERBOSE = 1
NB_CLASSES = 10
# number of outputs = number of digits
OPTIMIZER = SGD()
# SGD optimizer, explained later in this chapter
N_HIDDEN = 1024
VALIDATION_SPLIT=0.2
# how much TRAIN is reserved for VALIDATION

# %%
# data: shuffled and split between train and test sets
#
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# normalize
#
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# %%
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# %%
# 10 outputs
# final stage is softmax

# %%
model = Sequential()
model.add(Dense(NB_CLASSES, input_shape=(RESHAPED,)))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',optimizer=OPTIMIZER,metrics=['accuracy'])
history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=NB_EPOCH, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# # CIFAR-10 OPTIMIZER=SGD() NB_EPOCH = 20
# # BATCH_SIZE = 128
# # VERBOSE = 1
# # NB_CLASSES = 10
# # OPTIMIZER = SGD()
# # N_HIDDEN = 1024
# # VALIDATION_SPLIT=0.2
# # test accuracy = 0.48

# %%
# network and training
NB_EPOCH = 250
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = SGD() # optimizer, explained later in this chapter
N_HIDDEN = 1024
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 3072
#
X_train = X_train.reshape(50000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)
# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
optimizer=OPTIMIZER,
metrics=['accuracy'])
history = model.fit(X_train, Y_train,
batch_size=BATCH_SIZE, epochs=NB_EPOCH,
verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])

# %%
from tensorflow.keras.optimizers import RMSprop, Adam

# %% [markdown]
# # CIFAR-10 OPTIMIZER=RMSprop()
# # test accuracy=0.473

# %%
# network and training
NB_EPOCH = 250
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = RMSprop() # optimizer, explained later in this chapter
N_HIDDEN = 1024
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 3072
#
X_train = X_train.reshape(50000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)
# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
optimizer=OPTIMIZER,
metrics=['accuracy'])
history = model.fit(X_train, Y_train,
batch_size=BATCH_SIZE, epochs=NB_EPOCH,
verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# CIFAR-10 OPTIMIZER=Adam()
# test accuracy=

# %%
# network and training
NB_EPOCH = 250
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = Adam() # optimizer, explained later in this chapter
N_HIDDEN = 1024
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 3072
#
X_train = X_train.reshape(50000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)
# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
optimizer=OPTIMIZER,
metrics=['accuracy'])
history = model.fit(X_train, Y_train,
batch_size=BATCH_SIZE, epochs=NB_EPOCH,
verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# # CIFAR-10 20 EPOCH
# # SGD()     test accuracy=0.4803
# # RMSprop() test accuracy=0.473
# # Adam()    test accuracy=0.5131
#
# # CIFAR-10 250 EPOCH
# # SGD()     test accuracy=0.5546000003814697
# # RMSprop() test accuracy=0.4172999858856201
# # Adam()    test accuracy=0.4733999967575073

# %%
# network and training
NB_EPOCH = 20
BATCH_SIZE = 8
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = SGD() # optimizer, explained later in this chapter
N_HIDDEN = 1024
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)
# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
optimizer=OPTIMIZER,
metrics=['accuracy'])
history = model.fit(X_train, Y_train,
batch_size=BATCH_SIZE, epochs=NB_EPOCH,
verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])

# %%
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras.utils import np_utils
np.random.seed(1671) # for reproducibility
# network and training
NB_EPOCH = 250
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = SGD() # optimizer, explained later in this chapter
N_HIDDEN = 128
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
DROPOUT = 0.3
# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# normalize
X_train /= 255
X_test /= 255
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)
# M_HIDDEN hidden layers 10 outputs
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
optimizer=OPTIMIZER,
metrics=['accuracy'])
history = model.fit(X_train, Y_train,
batch_size=BATCH_SIZE, epochs=NB_EPOCH,
verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])

# %%
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras.utils import np_utils
np.random.seed(1671) # for reproducibility
# network and training
NB_EPOCH = 250
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = SGD() # optimizer, explained later in this chapter
N_HIDDEN = 128
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
DROPOUT = 0.3
# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# normalize
X_train /= 255
X_test /= 255
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)
# M_HIDDEN hidden layers 10 outputs
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
optimizer=OPTIMIZER,
metrics=['accuracy'])
history = model.fit(X_train, Y_train,
batch_size=BATCH_SIZE, epochs=NB_EPOCH,
verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])

# %%
# network and training
NB_EPOCH = 250
BATCH_SIZE = 8
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = RMSprop() # optimizer, explained later in this chapter
N_HIDDEN = 1024
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 3072
#
X_train = X_train.reshape(50000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)
# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
optimizer=OPTIMIZER,
metrics=['accuracy'])
history = model.fit(X_train, Y_train,
batch_size=BATCH_SIZE, epochs=NB_EPOCH,
verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# # CIFAR-10
#
# # NB_EPOCH = 250
# # BATCH_SIZE = 8
# # VERBOSE = 1
# # NB_CLASSES = 10 # number of outputs = number of digits
# # OPTIMIZER = RMSprop() # optimizer, explained later in this chapter
# # N_HIDDEN = 1024
# # VALIDATION_SPLIT=0.2
# # Test accuracy: 0.34459999203681946
